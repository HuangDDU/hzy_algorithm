# %%
import sys
sys.path += ["../23_12_22路径优化/"]
from main13_A_star import main as main_A_star 
from main14_transmitter_cost import main as main_transmitter_cost
from main7_map_visualization import visualization

# %% [markdown]
# 查看结果

# %%
def show_map(map):
    N = map.N

    for i in range(N):
        for j in range(N):
            node = map.node_matrix[i][j]
            print(node.distance, end=" ")
        print()

    print("==================================")
    for i in range(N):
        for j in range(N):
            node = map.node_matrix[i][j]
            if node.best_direction == "UP":
                print("↑", end=" ")
            elif node.best_direction == "RIGHT":
                print("→", end=" ")            
            elif node.best_direction == "DOWN":
                print("↓", end=" ")            
            elif node.best_direction == "LEFT":
                print("←", end=" ")
            else:
                print("U", end=" ")
        print()

# %%
map, provider, consumer_vector, transmitter_vector = main_A_star(conf_file="main14_transmitter_cost_map.txt")
visualization(map, provider, consumer_vector, transmitter_vector)
show_map(map)
# Out:
# manhattan_scale 1
# =======================================
# 1 4
# 2 2
# =======================================
# 3
# 2 2 2 0 1 0 1 2 0
# 2 1 1 0 2 0
# 1 1 1 0 3 0
# 1 0 1 1 1 0
# time score: 3.0
# cost score: 18
# =======================================
# 334857.5935113962
# 4 5 -1
# 3 2 2
# 3 1 0
# ==================================
# ↓ ↓ U
# → ↓ ↓
# → → U

# %%
map, provider, consumer_vector, transmitter_vector = main_transmitter_cost(conf_file="main14_transmitter_cost_map.txt")
visualization(map, provider, consumer_vector, transmitter_vector)
show_map(map)
# Out:
# manhattan_scale 1
# =======================================
# 1 17
# 2 8
# =======================================
# 1
# 2 2 2 0 1 0 1 2 0
# 2 0 1 1 1 0
# time score: 3.5
# cost score: 6
# =======================================
# 350955.57010080275
# 17 17 -1
# 16 14 8
# 9 7 0
# ==================================
# ↓ ↓ U
# ↓ ↓ ↓
# → → U
