# %%
from main15_other_map_new import main as old_main
from main16_format_transform import main 
from main16_map_visualization2 import visualization

# %% [markdown]
# 查看结果

# %%
def show_map(map):
    N = map.N

    for i in range(N):
        for j in range(N):
            node = map.node_matrix[i][j]
            print(node.distance, end=" ")
        print()

    print("==================================")
    for i in range(N):
        for j in range(N):
            node = map.node_matrix[i][j]
            if node.best_direction == "UP":
                print("↑", end=" ")
            elif node.best_direction == "RIGHT":
                print("→", end=" ")            
            elif node.best_direction == "DOWN":
                print("↓", end=" ")            
            elif node.best_direction == "LEFT":
                print("←", end=" ")
            else:
                print("U", end=" ")
        print()

# %%
map_filename = "main16_format_transform.txt"

# %% [markdown]
# 之前的方法，修改了评分函数

# %%
map, provider, consumer_vector, transmitter_vector = old_main(conf_file=map_filename)
visualization(map, provider, consumer_vector, transmitter_vector)
show_map(map)
# Out:
# manhattan_scale 52
# =======================================
# 1 35
# 2 50
# 3 50
# 4 36
# 5 36
# =======================================
# 4
# 4 0 1 0 1 0
# 3 0 1 0 2 0
# 3 1 2 0 3 0 0 4 0
# 1 1 3 1 1 1 1 2 1 1 3 2
# 3 4 2 1 4 2 1 5 2
# T1: 0; tmp_cost: 0
# T2: 0; tmp_cost: 0
# T3: 0; tmp_cost: 6
# T4: 0; tmp_cost: 4
# time score: 4.4
# cost score: 16
# =======================================
# 655562.4701346442
# -1 35 -1 -1 -1
# 50 34 50 -1 -1
# 101 33 133 134 36
# 1 17 18 19 20
# 0 100 133 134 36
# ==================================
# U ↓ U U U
# → ↓ ← U U
# ↓ ↓ ↓ ↓ ↓
# ↓ ← ← ← ←
# U ← ↑ ↑ ↑

# %% [markdown]
# 新方法，每隔transmitter需要的格式取出现次数最多的

# %%
map, provider, consumer_vector, transmitter_vector = main(conf_file=map_filename)
visualization(map, provider, consumer_vector, transmitter_vector)
show_map(map)
# Out:
# manhattan_scale 52
# =======================================
# 1 35
# 2 50
# 3 50
# 4 36
# 5 36
# =======================================
# 4
# 4 0 1 0 1 0
# 3 0 1 0 2 2
# 3 1 2 0 3 1 0 4 2
# 1 1 3 1 1 1 1 2 1 1 3 2
# 3 4 2 1 4 2 1 5 2
# T1: 2; tmp_cost: 0
# T2: 2; tmp_cost: 2
# T3: 1; tmp_cost: 2
# T4: 2; tmp_cost: 0
# time score: 3.2
# cost score: 16
# =======================================
# 656601.3584898136
# -1 35 -1 -1 -1
# 50 34 50 -1 -1
# 101 33 133 134 36
# 1 17 18 19 20
# 0 100 133 134 36
# ==================================
# U ↓ U U U
# → ↓ ← U U
# ↓ ↓ ↓ ↓ ↓
# ↓ ← ← ← ←
# U ← ↑ ↑ ↑
