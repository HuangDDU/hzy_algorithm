# %%
from main7_map import main
from main7_map_visualization import visualization

# %% [markdown]
# 正确示例

# %%
map, provider, consumer_vector, transmitter_vector = main(conf_file="main7_map_input.txt")
visualization(map, provider, consumer_vector, transmitter_vector)
# Out:
# =======================================
# 1 60
# 2 40
# 3 20
# =======================================
# 4
# 2 3 2 0 1 0 1 3 0
# 2 2 2 0 2 0 0 4 0
# 1 2 1 0 3 0
# 1 0 1 1 1 0
# 3 2 1 1 2 0

# %% [markdown]
# 2. 错误示例

# %%
map, provider, consumer_vector, transmitter_vector = main(conf_file="main7_map_input_error.txt")
visualization(map, provider, consumer_vector, transmitter_vector)
# Out:
# =======================================
# 1 60
# 2 40
# 3 20
# 4 30
# =======================================
# 4
# 2 3 2 0 1 0 1 3 0
# 2 2 2 0 2 0 0 4 0
# 1 2 1 0 3 0
# 1 0 1 1 1 0
# 3 2 1 1 2 0

# %%
map, provider, consumer_vector, transmitter_vector = main(conf_file="main7_map_input_error2.txt")
visualization(map, provider, consumer_vector, transmitter_vector)
# Out:
# =======================================
# 1 60
# 2 40
# 3 20
# 4 10
# =======================================
# 4
# 2 3 2 0 1 0 1 3 0
# 2 2 2 0 2 0 0 4 0
# 1 2 1 0 3 0
# 1 0 1 1 1 0
# 3 2 1 1 2 0
