# %%
import sys
sys.path += ["../23_12_22路径优化/"]
from main12_map_dijkstra_early_stop import main as main_dijkstra # 传统dijkstra
from main13_A_star import main as main_dijkstra_A_star # A*算法
from main7_map_visualization import visualization

# %% [markdown]
# 查看结果

# %%
def show_map(map):
    N = map.N

    for i in range(N):
        for j in range(N):
            node = map.node_matrix[i][j]
            print(node.distance, end=" ")
        print()

    print("==================================")
    for i in range(N):
        for j in range(N):
            node = map.node_matrix[i][j]
            if node.best_direction == "UP":
                print("↑", end=" ")
            elif node.best_direction == "RIGHT":
                print("→", end=" ")            
            elif node.best_direction == "DOWN":
                print("↓", end=" ")            
            elif node.best_direction == "LEFT":
                print("←", end=" ")
            else:
                print("U", end=" ")
        print()

# %%
map, provider, consumer_vector, transmitter_vector = main_dijkstra(conf_file="main13_A_star_map2.txt")
visualization(map, provider, consumer_vector, transmitter_vector)
show_map(map)
# Out:
# =======================================
# 1 21
# 2 11
# =======================================
# 2
# 3 3 2 0 1 0 0 2 0
# 0 3 1 1 1 0
# 3 4 1 1 2 0
# 21 20 18 15 18
# 20 18 15 11 15
# 18 15 11 6 11
# 15 11 6 0 6
# 18 15 11 6 11
# ==================================
# → → → ↓ ←
# → → → ↓ ←
# → → → ↓ ←
# → → → U ←
# ↑ ↑ ↑ ↑ ↑

# %%
map, provider, consumer_vector, transmitter_vector = main_dijkstra_A_star(conf_file="main13_A_star_map2.txt")
visualization(map, provider, consumer_vector, transmitter_vector)
show_map(map)
# Out:
# manhattan_scale 4
# =======================================
# 1 21
# 2 11
# =======================================
# 2
# 3 3 2 0 1 0 0 2 0
# 0 3 1 1 1 0
# 3 4 1 1 2 0
# 21 20 18 15 18
# -1 23 15 11 15
# -1 -1 11 6 11
# -1 11 6 0 6
# -1 15 11 6 11
# ==================================
# → → → ↓ ←
# U ↑ → ↓ ↓
# U U → ↓ ↓
# U → → U ←
# U → → ↑ ↑
