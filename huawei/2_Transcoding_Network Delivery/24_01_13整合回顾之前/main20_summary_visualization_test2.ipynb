# %%
import sys
sys.path += ["../24_01_05消息格式转换/"]
from main18_format_transform_weight import main as old_main
from main16_map_visualization2 import visualization
from main20_summary import main

# %% [markdown]
# 查看结果

# %%
def show_map(map):
    N = map.N

    for i in range(N):
        for j in range(N):
            node = map.node_matrix[i][j]
            print(node.distance, end=" ")
        print()

    print("==================================")
    for i in range(N):
        for j in range(N):
            node = map.node_matrix[i][j]
            if node.best_direction == "UP":
                print("↑", end=" ")
            elif node.best_direction == "RIGHT":
                print("→", end=" ")            
            elif node.best_direction == "DOWN":
                print("↓", end=" ")            
            elif node.best_direction == "LEFT":
                print("←", end=" ")
            else:
                print("U", end=" ")
        print()

# %%
map_filename = "main20_summary2.txt"

# %% [markdown]
# 之前的方法，dijkstra+合并

# %%
map, provider, consumer_vector, transmitter_vector = old_main(conf_file=map_filename)
visualization(map, provider, consumer_vector, transmitter_vector)
show_map(map)
# Out:
# manhattan_scale 16
# =======================================
# 1 46
# =======================================
# 2
# 2 2 1 0 1 0
# 1 2 1 0 2 0
# 1 1 1 1 1 0
# T1: 0; tmp_cost: 0
# T2: 0; tmp_cost: 0
# time score: 40.0
# cost score: 6
# =======================================
# 216623.4919609925
# -1 46 25
# 43 23 10
# 25 10 0
# ==================================
# U ↓ ↓
# → → ↓
# → → U

# %%
map, provider, consumer_vector, transmitter_vector = main(conf_file=map_filename)
visualization(map, provider, consumer_vector, transmitter_vector)
show_map(map)
# Out:
# manhattan_scale 16
# =======================================
# 1 43
# =======================================
# 2
# 2 2 1 0 1 0
# 1 2 1 0 2 0
# 1 1 1 1 1 0
# T1: 0; tmp_cost: 0
# T2: 0; tmp_cost: 0
# time score: 40.0
# cost score: 6
# =======================================
# 216623.4919609925
# -1 43 25
# 43 23 10
# 25 10 0
# ==================================
# U ↓ ↓
# → → ↓
# → → U
