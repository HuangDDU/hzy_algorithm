# %%
import sys
sys.path += ["../23_12_22路径优化/"]
from main13_A_star import main as main_A_star 
from main14_transmitter_cost import main as main_transmitter_cost
from main15_other_map import main as main_other_map
from main7_map_visualization import visualization

# %% [markdown]
# 查看结果

# %%
def show_map(map):
    N = map.N

    for i in range(N):
        for j in range(N):
            node = map.node_matrix[i][j]
            print(node.distance, end=" ")
        print()

    print("==================================")
    for i in range(N):
        for j in range(N):
            node = map.node_matrix[i][j]
            if node.best_direction == "UP":
                print("↑", end=" ")
            elif node.best_direction == "RIGHT":
                print("→", end=" ")            
            elif node.best_direction == "DOWN":
                print("↓", end=" ")            
            elif node.best_direction == "LEFT":
                print("←", end=" ")
            else:
                print("U", end=" ")
        print()

# %%
map_filename = "main15_other_map1.txt"

# %%
map, provider, consumer_vector, transmitter_vector = main_A_star(conf_file=map_filename)
visualization(map, provider, consumer_vector, transmitter_vector)
show_map(map)
# Out:
# manhattan_scale 523
# =======================================
# 1 316
# 2 -1
# 3 4761
# 4 2236
# 5 2965
# 6 -1
# 7 5242
# 8 3540
# 9 6725
# 10 -1
# 11 2439
# 12 -1
# 13 2088
# 14 -1
# 15 4140
# 16 -1
# 17 -1
# 18 -1
# 19 6971
# 20 -1
# 21 -1
# 22 -1
# 23 5970
# 24 3416
# 25 1457
# 26 8461
# 27 -1
# 28 2426
# 29 -1
# 30 612
# 31 3117
# =======================================
# 45
# 6 6 4 1 1 4 0 1 0 0 19 0 1 30 3
# 7 6 1 0 2 0
# 7 4 2 0 3 0 1 11 5
# 7 3 2 0 4 0 1 5 4
# 7 2 2 0 5 0 1 31 2
# 7 1 2 0 6 0 1 3 4
# 7 0 1 0 7 0
# 5 0 2 0 8 0 0 15 0
# 5 2 2 0 9 0 0 12 0
# 5 3 2 0 10 0 0 11 0
# 5 4 1 1 22 2
# 5 4 1 1 22 2
# 5 3 2 0 13 0 0 14 0
# 5 4 1 1 22 2
# 5 4 1 1 22 2
# 4 0 1 0 16 0
# 4 1 2 0 17 0 0 18 0
# 4 3 1 1 27 4
# 4 3 1 1 27 4
# 6 7 1 0 20 0
# 4 7 2 0 21 0 1 13 2
# 3 7 2 0 22 0 1 25 4
# 2 7 2 1 4 1 0 23 0
# 1 7 2 0 24 0 1 28 5
# 0 7 1 0 25 0
# 0 5 2 0 26 0 1 24 1
# 0 4 2 0 27 0 1 8 0
# 0 3 2 0 28 0 1 15 3
# 0 2 2 0 29 0 1 7 0
# 0 1 1 0 30 0
# 1 1 2 0 31 0 0 42 0
# 1 0 1 0 32 0
# 3 0 1 0 33 0
# 3 1 2 0 34 0 0 38 0
# 3 2 1 0 35 0
# 3 3 2 0 36 0 0 37 0
# 3 4 1 1 17 1
# 3 4 1 1 17 1
# 3 2 1 0 39 0
# 3 3 2 0 40 0 0 41 0
# 3 4 1 1 17 1
# 3 4 1 1 17 1
# 2 1 1 0 43 0
# 2 2 2 0 44 0 0 45 0
# 2 3 1 1 20 2
# 2 3 1 1 20 2
# time score: 1354.3225806451612
# cost score: 471
# =======================================
# 3174382.4514658046
# 5577 4813 4771 3801 3412 2605 2059 1778
# 5554 5250 5242 4140 3540 3416 2426 1761
# 6370 5970 -1 -1 -1 -1 2236 1571
# 6716 6971 -1 -1 -1 -1 1457 1225
# 6736 7733 8461 -1 -1 2088 1784 1089
# 6212 6725 -1 -1 -1 -1 316 1023
# 5250 4761 3117 2965 2439 612 0 241
# 4896 3957 3042 2936 2145 1307 577 616
# ==================================
# → → → → → → → ↓
# → ↑ ↑ ↑ ↑ ↑ → ↓
# ↑ ↑ U U U U → ↓
# ↑ ← U U U U → ↓
# ↓ ← ← U U → → ↓
# ↓ ← U U U U ↓ ↓
# ↓ ↓ ↓ ↓ ↓ → U ←
# → → → → → → ↑ ↑

# %%
map, provider, consumer_vector, transmitter_vector = main_transmitter_cost(conf_file=map_filename)
visualization(map, provider, consumer_vector, transmitter_vector)
show_map(map)
# Out:
# manhattan_scale 523
# =======================================
# 1 595
# 2 -1
# 3 5598
# 4 3073
# 5 3802
# 6 -1
# 7 6358
# 8 4656
# 9 7841
# 10 -1
# 11 3276
# 12 -1
# 13 2925
# 14 -1
# 15 5256
# 16 -1
# 17 -1
# 18 -1
# 19 8453
# 20 -1
# 21 -1
# 22 -1
# 23 7086
# 24 4532
# 25 2294
# 26 9577
# 27 -1
# 28 3263
# 29 -1
# 30 891
# 31 3954
# =======================================
# 43
# 6 6 4 1 1 4 0 1 0 0 29 0 1 30 3
# 7 6 1 0 2 0
# 7 4 2 0 3 0 1 11 5
# 7 3 2 0 4 0 1 5 4
# 7 2 2 0 5 0 1 31 2
# 7 1 2 0 6 0 1 3 4
# 7 0 1 0 7 0
# 5 0 2 0 8 0 0 15 0
# 5 2 2 0 9 0 0 12 0
# 5 3 2 0 10 0 0 11 0
# 5 4 1 1 22 2
# 5 4 1 1 22 2
# 5 3 2 0 13 0 0 14 0
# 5 4 1 1 22 2
# 5 4 1 1 22 2
# 4 0 2 0 16 0 0 26 0
# 3 0 1 0 17 0
# 3 1 2 0 18 0 0 22 0
# 3 2 1 0 19 0
# 3 3 2 0 20 0 0 21 0
# 3 4 1 1 17 1
# 3 4 1 1 17 1
# 3 2 1 0 23 0
# 3 3 2 0 24 0 0 25 0
# 3 4 1 1 17 1
# 3 4 1 1 17 1
# 4 1 2 0 27 0 0 28 0
# 4 3 1 1 27 4
# 4 3 1 1 27 4
# 6 7 1 0 30 0
# 4 7 2 0 31 0 1 13 2
# 3 7 2 0 32 0 1 25 4
# 2 7 2 1 4 1 0 33 0
# 1 7 2 0 34 0 1 28 5
# 0 7 1 0 35 0
# 0 5 2 0 36 0 1 24 1
# 0 4 2 0 37 0 1 8 0
# 0 3 2 0 38 0 1 15 3
# 0 2 2 1 7 0 0 39 0
# 0 1 1 0 40 0
# 2 1 1 0 41 0
# 2 2 2 0 42 0 0 43 0
# 2 3 1 1 20 2
# 2 3 1 1 20 2
# time score: 1318.1935483870968
# cost score: 453
# =======================================
# 3175086.9850954497
# 6414 5650 5608 4638 4249 3442 2896 2336
# 6949 6366 6358 5256 4656 4532 3263 2319
# 8044 7086 -1 -1 -1 -1 3073 2129
# 7919 8453 -1 -1 -1 -1 2294 1783
# 7573 8849 9577 -1 -1 2925 2621 1647
# 7049 7841 -1 -1 -1 -1 595 1581
# 6087 5598 3954 3802 3276 891 0 520
# 5454 4515 3600 3494 2703 1865 856 1174
# ==================================
# → → → → → → → ↓
# → ↑ ↑ ↑ ↑ ↑ → ↓
# ↑ ↑ U U U U → ↓
# ↓ ← U U U U → ↓
# ↓ ← ← U U → → ↓
# ↓ ← U U U U ↓ ↓
# ↓ ↓ ↓ ↓ ↓ → U ←
# → → → → → → ↑ ↑

# %%
map, provider, consumer_vector, transmitter_vector = main_other_map(conf_file=map_filename)
visualization(map, provider, consumer_vector, transmitter_vector)
show_map(map)
# Out:
# manhattan_scale 523
# =======================================
# 1 316
# 2 -1
# 3 5319
# 4 2794
# 5 3523
# 6 -1
# 7 6079
# 8 4377
# 9 7562
# 10 -1
# 11 2997
# 12 -1
# 13 2646
# 14 -1
# 15 4977
# 16 -1
# 17 -1
# 18 -1
# 19 8174
# 20 -1
# 21 -1
# 22 -1
# 23 6807
# 24 4253
# 25 2015
# 26 9298
# 27 -1
# 28 2984
# 29 -1
# 30 612
# 31 3675
# =======================================
# 20
# 6 6 4 1 1 4 0 1 0 0 10 0 1 30 3
# 7 6 1 0 2 0
# 7 4 2 0 3 0 1 11 5
# 7 3 2 0 4 0 1 5 4
# 7 2 2 0 5 0 1 31 2
# 7 1 2 1 3 4 0 6 0
# 7 0 1 0 7 0
# 5 0 2 1 9 3 0 8 0
# 4 0 2 0 9 0 1 26 0
# 3 0 1 1 19 5
# 6 7 1 0 11 0
# 4 7 2 0 12 0 1 13 2
# 3 7 2 0 13 0 1 25 4
# 2 7 2 1 4 1 0 14 0
# 1 7 2 0 15 0 1 28 5
# 0 7 1 0 16 0
# 0 5 2 0 17 0 1 24 1
# 0 4 2 0 18 0 1 8 0
# 0 3 2 0 19 0 1 15 3
# 0 2 2 1 7 0 0 20 0
# 0 1 1 1 23 1
# time score: 709.1935483870968
# cost score: 222
# =======================================
# 3190652.395070561
# 6135 5371 5329 4359 3970 3163 2617 2057
# 6670 6087 6079 4977 4377 4253 2984 2040
# 7765 6807 -1 -1 -1 -1 2794 1850
# 7640 8174 -1 -1 -1 -1 2015 1504
# 7294 8570 9298 -1 -1 2646 2342 1368
# 6770 7562 -1 -1 -1 -1 316 1302
# 5808 5319 3675 3523 2997 612 0 241
# 5175 4236 3321 3215 2424 1586 577 895
# ==================================
# → → → → → → → ↓
# → ↑ ↑ ↑ ↑ ↑ → ↓
# ↑ ↑ U U U U → ↓
# ↓ ← U U U U → ↓
# ↓ ← ← U U → → ↓
# ↓ ← U U U U ↓ ↓
# ↓ ↓ ↓ ↓ ↓ → U ←
# → → → → → → ↑ ↑
